# %% [markdown]
# # Placeholder for Pandas Options Notes

# %%
# Load required libraries
import pandas as pd
import numpy as np

# %%
# create dataframe with random data to use as example
example_df = pd.DataFrame(np.random.rand(100,30))
example_df
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.218248  0.923822  0.049745  0.480413  0.998990  0.928930  0.293297
# 1   0.512497  0.315794  0.915902  0.808155  0.057565  0.904718  0.466480
# 2   0.967659  0.985503  0.288868  0.517226  0.372552  0.889721  0.296211
# 3   0.656564  0.437431  0.952367  0.008399  0.576418  0.211667  0.221355
# 4   0.630750  0.980824  0.532275  0.898035  0.148579  0.528439  0.884756
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  0.668874  0.910302  0.148993  0.175442  0.957167  0.286416  0.217931
# 96  0.376981  0.073380  0.526506  0.135470  0.042080  0.467245  0.463857
# 97  0.326261  0.127162  0.562618  0.440768  0.963871  0.046773  0.060739
# 98  0.705876  0.074915  0.645719  0.822708  0.052325  0.754321  0.853078
# 99  0.398554  0.725285  0.140597  0.103492  0.707173  0.575351  0.190170
#
#           7         8         9   ...        20        21        22        23  \
# ...

# %% [markdown]
# ## Max rows / columns
#
# The default max number of rows displayed is 60 and the the default max number of columns displayed is 20.

# %%
print(pd.options.display.max_rows)
print(pd.options.display.max_columns)
# Out:
# 60
# 20

# %% [markdown]
# If you have a dataframe with more rows/columns, the middle rows/columns will be truncated when the dataframe is displayed (see above example).
#
# You can set the max_rows/max_columns option larger if you want to display more rows.

# %%
pd.options.display.max_columns = 110
example_df
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.218248  0.923822  0.049745  0.480413  0.998990  0.928930  0.293297
# 1   0.512497  0.315794  0.915902  0.808155  0.057565  0.904718  0.466480
# 2   0.967659  0.985503  0.288868  0.517226  0.372552  0.889721  0.296211
# 3   0.656564  0.437431  0.952367  0.008399  0.576418  0.211667  0.221355
# 4   0.630750  0.980824  0.532275  0.898035  0.148579  0.528439  0.884756
# 5   0.293683  0.550299  0.470582  0.394182  0.748944  0.273347  0.210372
# 6   0.139761  0.981733  0.607824  0.375008  0.314947  0.855776  0.516653
# 7   0.902366  0.910710  0.696644  0.092347  0.742796  0.656520  0.303381
# 8   0.464743  0.617243  0.511149  0.357212  0.068077  0.488281  0.818594
# 9   0.782751  0.574390  0.734931  0.766226  0.710190  0.986907  0.346807
# 10  0.061538  0.376572  0.758446  0.304650  0.943289  0.436786  0.493185
# 11  0.888188  0.180931  0.939205  0.131817  0.699715  0.050416  0.183742
# ...

# %% [markdown]
# ## set width of cells
# ## set display precision
# ## set decimal formats
#
# ## Reset settings to default
#
# ## Other
# ### Further Reading
# ### Versions Used
